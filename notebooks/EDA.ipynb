# %% [markdown]
# # Quiten Healthcare Project

# %% [markdown]
# ### 01 - Import statements and Loading dataset

# %%
cd ..
# Out:
# /Users/vitrac/Desktop/M2 HEC/05 - Quinten Healthcare/quinten_healthcare

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from src.data_processing.preprocessing import process_dataframe
import pandas as pd

file_path = 'data/raw_data_healthcare.csv'
df = pd.read_csv(file_path)
df = process_dataframe(df)
df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vitrac/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/vitrac/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    text_index                                    medication  rate  \
# 0           0       inflectra infliximab for crohns disease   1.0
# 1           1  remicade infliximab for rheumatoid arthritis   NaN
# 2           2    remicade infliximab for ulcerative colitis   1.0
# 3           3       inflectra infliximab for crohns disease   1.0
# 4           4    remicade infliximab for ulcerative colitis  10.0
#
#                                              comment  \
# 0  Insurance forced me to switch to inflectra due...
# 1  My wife had RA from when she was a child. She ...
# 2  This medication Remicade made me in constant p...
# 3  I have Fistulizing Crohn's, dx'd 6 yrs ago @ 3...
# ...

# %% [markdown]
# ### 02 - EDA Plots
#
# 1 - Pie chart of treatments

# %%
from src.plots.EDA_plots import plot_treatments_pie_chart

plot_treatments_pie_chart(df, 
                        rate_filter=False, 
                        rate_value=3)

# %% [markdown]
# 2 - Histograms of ratings

# %%
from src.plots.EDA_plots import plot_rates_histograms

plot_rates_histograms(df, 
                    treatment_filter=False, 
                    treatment_value='tysabri')

# %% [markdown]
# 3 - Most Common group of words

# %%
from src.plots.EDA_plots import plot_most_common_unique_words
from src.plots.EDA_plots import plot_most_pair_of_words

plot_most_common_unique_words(df, n=20)
plot_most_pair_of_words(df, n=20)
